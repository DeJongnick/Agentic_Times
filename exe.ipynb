# %%
from agents.orchestrator import exe

# %%
exe('Why Yann Lecun rumored to quit Meta?', authors=['Léo Bouchand','Nicolas Le Jeune'])
# Out:
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: ee6b7b5a-7ad5-4688-910a-516c77239973)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# Model loaded.
# Loaded 45915 embeddings and 45915 metadata entries
#
# --- Iteration 1 ---
# Critic note: 7.5 / 10 (threshold: 8.0)
#
# Current article draft:
#
# [title] Why Yann LeCun Rumored to Quit Meta?
#
# [subtitle] Introduction to the Speculation
# [paragraph] Rumors are swirling around Yann LeCun, Meta’s Chief Scientist in Artificial Intelligence, suggesting that he may be planning to leave the tech giant. LeCun has been instrumental in shaping the company's AI initiatives and has played a critical role in developing technologies that underpin Meta’s ambitious projects.
# ...
