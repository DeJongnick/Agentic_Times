# %% [markdown]
# ## Embeddings des articles (data/raw)
#
# Ce notebook extrait le texte des fichiers HTML, crée des chunks, génère des embeddings avec un modèle open‑source `sentence-transformers`, puis sauvegarde:
# - `data/vectors_base/embeddings.npy`
# - `data/vectors_base/metadata.jsonl`
#
# Paramètres principaux dans la cellule d’exécution: `CHUNK_SIZE`, `OVERLAP`, `BATCH_SIZE`, `MODEL_NAME`.

# %%
# Embeddings pipeline: HTML -> chunks -> hashing embeddings -> save

from __future__ import annotations

import os
import re
import json
import math
from pathlib import Path
from typing import List, Dict, Tuple, Iterable, Optional
from html import unescape
import numpy as np

# %%
# Project paths (robust for notebooks; cwd == ntb/)
ROOT = Path.cwd().parent
RAW_DIR = ROOT / "data" / "raw"
OUT_DIR = ROOT / "data" / "vectors_base"
OUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"ROOT: {ROOT}")
print(f"RAW_DIR: {RAW_DIR}")
print(f"OUT_DIR: {OUT_DIR}")
# Out:
# ROOT: /Users/perso/Documents/Agents/Agentic_Times
# RAW_DIR: /Users/perso/Documents/Agents/Agentic_Times/data/raw
# OUT_DIR: /Users/perso/Documents/Agents/Agentic_Times/data/vectors_base

# %%
def html_to_text(html: str) -> str:
    text = re.sub(r"<script[\s\S]*?</script>", " ", html, flags=re.IGNORECASE)
    text = re.sub(r"<style[\s\S]*?</style>", " ", text, flags=re.IGNORECASE)
    text = re.sub(r"<[^>]+>", " ", text)
    text = unescape(text)
    text = re.sub(r"\s+", " ", text)
    return text.strip()


def simple_tokenize(text: str) -> List[str]:
    text = text.lower()
    tokens = re.findall(r"[a-z0-9]+", text)
    return tokens


def chunk_tokens(tokens: List[str], chunk_size: int = 500, overlap: int = 50) -> List[List[str]]:
    if chunk_size <= 0:
        raise ValueError("chunk_size must be > 0")
    if overlap < 0 or overlap >= chunk_size:
        raise ValueError("overlap must be >= 0 and < chunk_size")

    chunks = []
    start = 0
    step = chunk_size - overlap
    while start < len(tokens):
        end = min(start + chunk_size, len(tokens))
        chunks.append(tokens[start:end])
        if end == len(tokens):
            break
        start += step
    return chunks


def det_hash(token: str) -> int:
    h = 1469598103934665603
    for c in token:
        h ^= ord(c)
        h = (h * 1099511628211) & 0xFFFFFFFFFFFFFFFF
    return h


def hashing_embedding(tokens: List[str], dim: int = 768) -> np.ndarray:
    vec = np.zeros(dim, dtype=np.float32)
    for t in tokens:
        h = det_hash(t)
        idx = h % dim
        sign = -1.0 if ((h >> 63) & 1) else 1.0
        vec[idx] += sign

    norm = float(np.linalg.norm(vec))
    if norm > 0:
        vec /= norm
    return vec

def collect_html_files(raw_dir: Path) -> List[Path]:
    return sorted([p for p in raw_dir.glob("**/*.html") if p.is_file()])


def process_file(path: Path, chunk_size: int, overlap: int) -> List[Dict]:
    html = path.read_text(encoding="utf-8", errors="ignore")
    text = html_to_text(html)
    tokens = simple_tokenize(text)
    token_chunks = chunk_tokens(tokens, chunk_size=chunk_size, overlap=overlap)

    chunks = []
    for i, tok_chunk in enumerate(token_chunks):
        chunk_text = " ".join(tok_chunk)
        chunks.append({
            "source": str(path.relative_to(RAW_DIR)),
            "chunk_index": i,
            "num_tokens": len(tok_chunk),
            "text": chunk_text,
        })
    return chunks


def build_embeddings(raw_dir: Path, chunk_size: int = 500, overlap: int = 50, dim: int = 768) -> Tuple[np.ndarray, List[Dict]]:
    files = collect_html_files(raw_dir)
    print(f"Found {len(files)} HTML files.")

    all_meta: List[Dict] = []
    vectors: List[np.ndarray] = []

    for f in files:
        chunks = process_file(f, chunk_size=chunk_size, overlap=overlap)
        for ch in chunks:
            toks = ch["text"].split()
            vec = hashing_embedding(toks, dim=dim)
            vectors.append(vec)
            all_meta.append({k: v for k, v in ch.items() if k != "text"})
        print(f"Processed {f.name}: {len(chunks)} chunks")

    if len(vectors) == 0:
        return np.zeros((0, dim), dtype=np.float32), []

    emb = np.vstack(vectors)
    return emb, all_meta

# %% [markdown]
# ### Notes
# - Pipeline: extraction HTML → tokenisation → chunking → embeddings (open‑source `sentence-transformers`).
# - Ajustez `CHUNK_SIZE`, `OVERLAP`, `BATCH_SIZE`, et `MODEL_NAME` si besoin.
# - Sorties:
#   - `data/vectors_base/embeddings.npy`: matrice float32 (n_chunks × dim_modèle)
#   - `data/vectors_base/metadata.jsonl`: JSONL aligné (par ligne: `source`, `chunk_index`, `num_tokens`, `row_index`).

# %%
try:
    from sentence_transformers import SentenceTransformer
except Exception as e:
    raise RuntimeError(
        "sentence-transformers is required. Install with: pip install sentence-transformers"
    ) from e

MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"  # small, fast, high-quality
print(f"Loading model: {MODEL_NAME}")
model: SentenceTransformer = SentenceTransformer(MODEL_NAME)
print("Model loaded.")
# Out:
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# Model loaded.

# %%
def build_embeddings_model(
    raw_dir: Path,
    model: "SentenceTransformer",
    chunk_size: int = 500,
    overlap: int = 50,
    batch_size: int = 64,
    convert_to_numpy: bool = True,
    normalize_embeddings: bool = True,
) -> Tuple[np.ndarray, List[Dict]]:
    files = collect_html_files(raw_dir)
    print(f"Found {len(files)} HTML files.")

    all_chunks: List[Dict] = []
    for f in files:
        chs = process_file(f, chunk_size=chunk_size, overlap=overlap)
        all_chunks.extend(chs)
        print(f"Prepared {f.name}: {len(chs)} chunks")

    if not all_chunks:
        return np.zeros((0, model.get_sentence_embedding_dimension()), dtype=np.float32), []

    texts = [c["text"] for c in all_chunks]

    embeddings = model.encode(
        texts,
        batch_size=batch_size,
        show_progress_bar=True,
        convert_to_numpy=convert_to_numpy,
        normalize_embeddings=normalize_embeddings,
    )

    metadata = []
    for i, ch in enumerate(all_chunks):
        m = {k: v for k, v in ch.items() if k != "text"}
        metadata.append(m)

    if isinstance(embeddings, list):
        embeddings = np.asarray(embeddings, dtype=np.float32)

    return embeddings.astype(np.float32, copy=False), metadata

# %%
CHUNK_SIZE = 500
OVERLAP = 50
BATCH_SIZE = 64

embeddings, metadata = build_embeddings_model(
    RAW_DIR,
    model=model,
    chunk_size=CHUNK_SIZE,
    overlap=OVERLAP,
    batch_size=BATCH_SIZE,
    convert_to_numpy=True,
    normalize_embeddings=True,
)
print(f"Embeddings shape: {embeddings.shape}")

emb_path = OUT_DIR / "embeddings.npy"
np.save(emb_path, embeddings)
print(f"Saved embeddings to {emb_path}")

meta_path = OUT_DIR / "metadata.jsonl"
with meta_path.open("w", encoding="utf-8") as f:
    for i, m in enumerate(metadata):
        m_out = dict(m)
        m_out["row_index"] = i
        f.write(json.dumps(m_out, ensure_ascii=False) + "\n")
print(f"Saved metadata to {meta_path}")
# Out:
# Found 16573 HTML files.
# Prepared 1-000-for-a-one-hour-appointment-why-are-fees-for-australia-s-specialist-doctors-skyrocketing.html: 4 chunks
# Prepared 1-5m-foreign-workers-already-in-uk-could-face-longer-wait-for-permanent-settlement.html: 3 chunks
# Prepared 10-of-the-best-chocolate-advent-calendars.html: 1 chunks
# Prepared 10-of-the-best-secret-gardens-in-europe-s-major-cities.html: 3 chunks
# Prepared 10-reasons-to-visit-spain-in-2025-new-holidays-hikes-and-cultural-highlights.html: 3 chunks
# Prepared 10-year-old-rape-victim-forced-to-travel-from-ohio-to-indiana-for-abortion.html: 2 chunks
# Prepared 100-gaza-children-hope-to-be-evacuated-to-uk-for-urgent-medical-care.html: 2 chunks
# Prepared 13-going-on-30-the-musical-review-jennifer-garner-romcom-returns-with-goofy-charm.html: 1 chunks
# Prepared 20-000-monkeys-inside-the-booming-illicit-trade-for-lab-animals.html: 3 chunks
# Prepared 20-a-night-for-one-of-the-most-peaceful-locations-in-the-world-readers-favourite-remote-stays.html: 3 chunks
# Prepared 2020s-on-course-to-be-weakest-decade-for-global-economy-since-1960s-says-world-bank.html: 2 chunks
# Prepared 2024-witnessed-absolute-failure-of-west-to-lead-fight-for-human-rights-says-watchdog.html: 2 chunks
# Prepared 2025-on-track-to-beat-uk-record-for-wildfires-warn-firefighters.html: 1 chunks
# Prepared 23andme-back-on-the-auction-block-after-former-ceo-makes-11th-hour-bid.html: 2 chunks
# Prepared 23andme-s-demise-is-a-warning-the-us-needs-to-overhaul-genetic-data-protection.html: 3 chunks
# Prepared 2hollis-star-review-sounds-like-the-internet-and-bound-for-stardom.html: 1 chunks
# Prepared 3-i-atlas-a-rare-comet-from-beyond-our-solar-system-is-being-closely-tracked-what-can-it-teach-us.html: 3 chunks
# Prepared 30-of-the-best-uk-pubs-for-an-autumn-escape-with-great-food.html: 10 chunks
# Prepared 30-things-we-love-in-the-world-of-food-2025.html: 18 chunks
# Prepared 37-000-more-children-affected-by-brutal-two-child-benefit-cap-data-shows.html: 2 chunks
# Prepared 38-londres-street-by-philippe-sands-review-pinochet-and-the-nazis.html: 2 chunks
# Prepared 48-dead-after-soviet-era-passenger-plane-crashes-in-russia-s-far-east.html: 1 chunks
# Prepared 4chan-unlikely-to-be-included-in-australia-s-under-16s-social-media-ban-esafety-commissioner-says.html: 2 chunks
# Prepared 5-2m-for-a-duct-taped-banana-has-the-buyer-of-maurizio-cattelan-s-artwork-slipped-up.html: 3 chunks
# Prepared 500-000-stolen-in-australian-super-fund-data-breach.html: 3 chunks
# Prepared 500m-thames-water-desalination-plant-has-provided-just-seven-days-water-over-15-years.html: 3 chunks
# Prepared 65-000-years-a-short-history-of-australian-art-a-grand-disturbing-and-provocative-exhibition.html: 3 chunks
# Prepared 7-000-steps-a-day-could-be-enough-to-improve-health-say-researchers.html: 2 chunks
# Prepared 7-6bn-of-stablecoin-tether-redeemed-since-start-of-crypto-crisis.html: 2 chunks
# Prepared 7-7-homegrown-terror-review-the-shock-of-that-horrific-day-will-never-subside.html: 2 chunks
# Prepared 90-of-great-lakes-water-samples-have-unsafe-microplastic-levels-report.html: 1 chunks
# Prepared 996-work-culture-is-sad-and-inhumane-whatever-s-wrong-with-888-or-even-000.html: 2 chunks
# Prepared a-10-week-wait-for-a-coil-british-women-are-facing-a-quiet-crisis-in-contraceptive-care.html: 3 chunks
# Prepared a-14-step-guide-to-taking-a-fleeting-break-from-social-media.html: 2 chunks
# Prepared a-160-year-old-campaign-against-civil-rights-heads-to-the-supreme-court.html: 7 chunks
# Prepared a-2018-rugby-league-six-nations-on-cards-but-ireland-not-keen-on-england-b.html: 2 chunks
# Prepared a-66-minute-stress-bomb-tv-s-most-intense-episodes-ever.html: 4 chunks
# Prepared a-back-to-work-approach-to-mental-illness-is-no-panacea.html: 1 chunks
# Prepared a-ban-on-forever-chemicals-would-be-best.html: 1 chunks
# Prepared a-ban-on-smoking-in-french-films-the-idea-makes-me-fume.html: 2 chunks
# Prepared a-bargaining-breakdown-and-strikes-the-bitter-union-fight-at-starbucks.html: 2 chunks
# Prepared a-battlefield-hit-by-hs2-and-planning-rules.html: 1 chunks
# Prepared a-bellwether-of-change-speed-of-glacier-shrinking-on-remote-heard-island-sounds-alarm.html: 2 chunks
# Prepared a-berlin-audience-has-fake-faeces-thrown-at-them-and-is-moved-to-tears-so-am-i.html: 3 chunks
# Prepared a-better-life-is-possible-but-only-if-you-dive-deep-into-your-unconscious.html: 3 chunks
# Prepared a-bias-monitor-for-cbs-news-is-a-bad-idea-here-s-why.html: 2 chunks
# Prepared a-biblical-hatred-is-engulfing-both-sides-in-the-gaza-conflict-and-blinding-them-to-reason.html: 3 chunks
# Prepared a-big-chance-for-the-populists-estonian-city-alert-to-the-threat-of-moscow-in-its-mayoral-election.html: 4 chunks
# Prepared a-billion-people-backing-you-china-transfixed-as-musk-turns-against-trump.html: 1 chunks
# Prepared a-bitter-blow-british-pubs-restaurants-and-hospitality-firms-brace-for-rise-in-nics.html: 4 chunks
# Prepared a-book-is-being-marketed-with-mayo-scented-ink-jealous-me.html: 3 chunks
# Prepared a-brief-history-of-the-end-of-the-f-cking-world-by-tom-phillips-review-apocalypse-not.html: 3 chunks
# Prepared a-british-export-the-us-didn-t-need-a-cosy-relationship-between-editor-and-proprietor.html: 3 chunks
# Prepared a-broader-view-of-us-jews-support-for-israel.html: 1 chunks
# Prepared a-broken-housing-market-is-driving-inequality-right-across-europe-and-fuelling-the-far-right.html: 2 chunks
# Prepared a-broken-system-full-of-criminality-and-death-the-podcast-lifting-the-lid-on-what-happens-to-the-uk-s-rubbish.html: 3 chunks
# Prepared a-brush-with-cezanne-in-aix-en-provence-france-a-blockbuster-retrospective-comes-to-town.html: 4 chunks
# Prepared a-carbon-tax-to-clip-the-wings-of-frequent-flyers.html: 1 chunks
# Prepared a-caring-neighbor-a-nurse-who-pulled-double-shifts.html: 41 chunks
# Prepared a-cascade-can-be-more-positive-social-tipping-points-expert-on-fixing-climate-crisis.html: 4 chunks
# Prepared a-cascade-of-terrible-things-documentary-pieces-together-rust-shooting-tragedy.html: 4 chunks
# Prepared a-case-study-in-groupthink-were-liberals-wrong-about-the-pandemic.html: 5 chunks
# Prepared a-challenge-for-readers-to-go-plastic-free.html: 1 chunks
# Prepared a-chance-encounter-with-santa-in-spain.html: 1 chunks
# Prepared a-chance-for-labour-to-honour-its-pledge-on-international-development.html: 1 chunks
# Prepared a-chaotic-nhs-is-why-people-now-go-private.html: 1 chunks
# Prepared a-china-led-global-system-alongside-that-of-the-us-is-xi-jinping-s-ultimate-aim.html: 1 chunks
# Prepared a-chronic-lack-of-ambition-has-laid-waste-to-tottenham.html: 2 chunks
# Prepared a-city-boy-reading-of-the-s-mi-artist-m-ret-nne-sara-s-work.html: 1 chunks
# Prepared a-class-act-tim-allan-the-former-blair-smoother-recalled-to-downing-street.html: 3 chunks
# Prepared a-clear-set-of-actions-is-needed-to-improve-nhs-maternity-services.html: 1 chunks
# Prepared a-clever-agent-notes-from-watchers-of-spy-kim-philby-made-public-for-first-time.html: 3 chunks
# Prepared a-cloak-some-monsters-and-a-bicycle-marguerite-o-molloy-s-best-phone-picture.html: 1 chunks
# Prepared a-clockwork-orange-estate-fights-art-washing-redevelopment-plans.html: 2 chunks
# Prepared a-collective-anxiety-attack-the-psychology-of-unexplained-drone-sightings-across-europe.html: 3 chunks
# Prepared a-college-that-offers-teenage-refugees-a-comprehensive-education.html: 1 chunks
# Prepared a-compilation-of-terrorists-by-blake-morrison.html: 1 chunks
# Prepared a-complete-unknown-review-timoth-e-chalamet-s-bob-dylan-is-an-electric-revelation.html: 3 chunks
# Prepared a-computer-a-radio-a-drone-and-a-shotgun-how-missionaries-are-reaching-out-to-brazil-s-isolated-peoples.html: 5 chunks
# Prepared a-cop-of-peace-how-can-authoritarian-human-rights-trashing-azerbaijan-possibly-host-that.html: 2 chunks
# Prepared a-cornucopia-the-coming-football-season-will-set-a-uk-record-for-viewers-and-income.html: 3 chunks
# Prepared a-country-retreat-that-s-off-grid-but-online.html: 1 chunks
# Prepared a-crypto-obsession-and-early-crocs-investment-lie-behind-an-outsider-s-hustle-mentality.html: 3 chunks
# Prepared a-cultural-embarrassment-anger-as-male-sculptor-commissioned-for-statue-of-suffragist.html: 3 chunks
# Prepared a-cultural-revolution-trump-s-america-feels-oddly-familiar-to-those-watching-from-china.html: 3 chunks
# Prepared a-da-muluneh-on-capturing-the-uk-s-contradictions-it-s-hard-to-imagine-there-are-people-going-hungry.html: 2 chunks
# Prepared a-dance-done-by-the-whole-world-south-african-choreographer-dreams-of-global-reach.html: 2 chunks
# Prepared a-dead-team-girona-staring-into-the-abyss-after-crushing-loss-to-levante.html: 5 chunks
# Prepared a-deadly-scheme-palestinians-face-indiscriminate-gunfire-at-food-sites.html: 5 chunks
# Prepared a-defining-moment-trinidad-and-tobago-at-a-crossroads-as-oil-runs-out.html: 4 chunks
# Prepared a-different-level-than-2020-trump-s-plan-to-steal-election-is-taking-shape.html: 6 chunks
# Prepared a-disaster-for-all-of-us-us-scientists-describe-impact-of-trump-cuts.html: 4 chunks
# Prepared a-doctor-s-bracing-advice-to-new-mums.html: 1 chunks
# Prepared a-drag-queen-stands-at-a-site-of-violence-lee-ann-olwage-s-best-photograph.html: 2 chunks
# Prepared a-drill-a-bread-knife-and-a-bottle-of-wine-your-most-treasured-wedding-gifts.html: 2 chunks
# Prepared a-drop-in-the-ocean-does-experimental-technology-hold-the-key-to-saving-the-world-s-seas.html: 4 chunks
# Prepared a-dustpan-and-brush-with-fine-art.html: 1 chunks
# Prepared a-dystopian-surveillance-fear-has-become-reality-in-texas.html: 3 chunks
# Prepared a-fair-price-to-the-public-for-water-nationalisation.html: 1 chunks
# Prepared a-fairer-system-would-make-paying-taxes-more-palatable.html: 1 chunks
# Prepared a-fascinating-insight-into-pandemic-psychology-how-animal-crossing-gave-us-an-escape.html: 3 chunks
# Prepared a-fashion-and-art-moment-how-mediums-mix-at-frieze-art-fair.html: 2 chunks
# Prepared a-fatal-blow-italian-producers-fear-effects-of-trump-s-war-against-pasta.html: 2 chunks
# Prepared a-fatal-drop-what-do-we-know-about-the-drugs-500-times-stronger-than-heroin-taking-australian-lives.html: 4 chunks
# Prepared a-festival-of-korean-dance-jungle-review-muscular-intensity-and-wonder.html: 1 chunks
# Prepared a-film-about-an-audacious-art-heist-inside-the-mastermind-the-timeliest-movie-ever.html: 4 chunks
# Prepared a-fine-balance-of-hope-and-reality-in-stroke-recovery.html: 2 chunks
# Prepared a-fork-in-the-road-laundry-sorting-robot-spurs-ai-hopes-and-fears-at-europe-s-biggest-tech-event.html: 3 chunks
# Prepared a-french-university-is-offering-scientific-asylum-for-us-talent-the-brain-drain-has-started.html: 3 chunks
# Prepared a-fresh-use-for-35mm-film-canisters.html: 1 chunks
# Prepared a-full-circle-moment-for-me-jack-wilshere-confirmed-as-luton-manager.html: 1 chunks
# Prepared a-fundamental-right-a-timeline-of-us-abortion-rights-since-roe-v-wade.html: 6 chunks
# Prepared a-future-of-mobile-centric-healthcare-could-save-lives.html: 2 chunks
# Prepared a-future-on-our-terms-how-community-energy-is-lighting-up-latin-america.html: 3 chunks
# Prepared a-future-worth-fighting-for-five-health-experts-on-the-state-of-the-nhs-at-75.html: 3 chunks
# Prepared a-gender-critical-book-at-scotland-s-national-library-is-the-latest-in-a-long-line-of-cancellations.html: 3 chunks
# Prepared a-genuine-honour-matt-bloomfield-confirmed-as-luton-s-manager.html: 1 chunks
# Prepared a-good-deal-or-a-good-deal-of-waste-how-to-be-more-conscious-about-your-consumption-during-sales-periods.html: 3 chunks
# Prepared a-good-moment-in-time-for-us-firefox-head-on-ai-browsers-and-what-s-next-for-the-web.html: 4 chunks
# Prepared a-good-thing-for-children-summer-camps-at-risk-in-uk-as-costs-rise.html: 3 chunks
# Prepared a-graduate-s-arrest-and-trump-s-pincer-attack-on-higher-education.html: 4 chunks
# Prepared a-great-of-australian-sport-how-minjee-lee-rose-to-top-in-a-golden-era-of-women-s-golf.html: 2 chunks
# Prepared a-great-way-of-getting-under-the-skin-of-a-city-the-rise-of-urban-treasure-hunts.html: 3 chunks
# Prepared a-guide-to-greener-banking-i-divested-my-personal-finances-and-you-can-too-here-s-how.html: 3 chunks
# Prepared a-hacker-s-dream-britons-on-keir-starmer-s-plan-for-digital-id-cards.html: 3 chunks
# Prepared a-hadeda-nothing-can-quite-capture-the-sound-of-these-birds-because-it-s-mainly-just-rude-noise.html: 2 chunks
# Prepared a-hard-hat-a-hi-vis-jacket-and-a-stepladder-my-very-scientific-suitcase-stress-test.html: 2 chunks
# Prepared a-heaving-bridgerton-cleavage-or-bloody-decapitation-what-your-favourite-era-of-history-says-about-you.html: 1 chunks
# Prepared a-heifer-came-into-the-bedroom-kevin-survived-the-nsw-floods-but-his-dairy-farm-might-not.html: 3 chunks
# Prepared a-hi-tech-health-prediction-that-i-could-do-without.html: 1 chunks
# Prepared a-hike-a-swim-then-a-full-on-rave-is-this-britain-s-most-remote-club-night.html: 2 chunks
# Prepared a-hostile-takeover-ousted-cdc-official-raises-alarm-over-rfk-jr-approach-to-infectious-disease.html: 3 chunks
# Prepared a-house-of-dynamite-is-both-political-fantasy-and-major-disappointment.html: 3 chunks
# Prepared a-house-of-dynamite-mr-scorsese-and-new-alan-partridge-what-s-new-to-streaming-in-australia-in-october.html: 6 chunks
# Prepared a-house-of-dynamite-writer-respectfully-disagrees-with-pentagon-s-complaints-about-nuclear-missile-thriller.html: 1 chunks
# Prepared a-hub-of-humanity-national-railway-museum-space-reopens-after-11m-refit.html: 2 chunks
# Prepared a-huge-gap-in-the-market-how-do-you-scout-for-scouts-in-women-s-football.html: 3 chunks
# Prepared a-huge-opportunity-quantum-leap-for-uk-as-tech-industry-receives-100m-boost.html: 2 chunks
# Prepared a-huge-reset-gender-critical-activists-and-trans-rights-campaigners-react-to-supreme-court-ruling.html: 2 chunks
# Prepared a-human-rights-disaster-immigrants-sent-into-guant-namo-black-hole-despite-no-proof-of-crime.html: 4 chunks
# Prepared a-job-is-like-finding-a-needle-in-a-haystack-how-dudley-became-centre-of-uk-s-youth-jobs-crisis.html: 4 chunks
# Prepared a-journey-through-the-hyper-political-world-of-microchips.html: 4 chunks
# Prepared a-key-medicine-agency-has-left-britain-this-is-the-start-of-a-brexodus.html: 2 chunks
# Prepared a-knock-on-the-roof-review-slowly-searing-account-of-life-lived-in-a-state-of-constant-terror.html: 2 chunks
# Prepared a-landmark-moment-lions-and-suns-fans-gear-up-for-match-billed-as-biggest-in-queensland-afl-history.html: 3 chunks
# Prepared a-last-resort-is-culling-foxes-the-only-way-to-save-britain-s-vanishing-curlews.html: 2 chunks
# Prepared a-leagues-seek-to-stop-arms-race-with-strict-3m-salary-cap.html: 2 chunks
# Prepared a-leaked-memo-a-maga-style-hat-and-a-trail-of-broken-pledges-it-s-labour-s-great-housing-betrayal.html: 3 chunks
# Prepared a-lesson-from-brazil-where-gig-workers-have-rallied-against-the-right.html: 3 chunks
# Prepared a-lesson-like-no-other-readers-favourite-learning-holidays.html: 3 chunks
# Prepared a-level-english-voluntary-work-delayed-citizenship-it-s-labour-s-orwellian-two-minutes-hate-for-immigrants.html: 3 chunks
# Prepared a-level-results-in-england-expected-to-return-to-near-pre-pandemic-levels.html: 3 chunks
# Prepared a-levels-and-gcses-need-overhaul-to-keep-pace-with-generative-ai-experts-say.html: 2 chunks
# Prepared a-life-of-captivity-canada-refuses-marine-park-s-request-to-export-its-whales-to-china.html: 2 chunks
# Prepared a-london-2040-olympics-is-alluring-but-do-gold-medals-bring-cities-a-golden-future.html: 3 chunks
# Prepared a-lot-of-pride-and-joy-the-first-nations-team-representing-australia-at-the-venice-biennale-of-architecture.html: 3 chunks
# Prepared a-lot-of-question-marks-70m-renewable-energy-microgrid-project-divides-daintree.html: 3 chunks
# Prepared a-lovely-opportunity-to-capture-a-funny-moment-lorraine-poole-s-best-phone-picture.html: 1 chunks
# Prepared a-luxury-cruise-ship-stopped-at-a-remote-australian-island-suzanne-rees-was-left-behind-and-died-alone.html: 4 chunks
# Prepared a-man-and-a-camera-review-doorstep-prank-movie-is-pass-agg-psychological-study.html: 1 chunks
# Prepared a-manatee-imagine-eating-lettuce-under-water.html: 2 chunks
# Prepared a-map-a-myth-and-a-pre-incan-lagoon-the-man-who-brought-water-back-to-a-drought-ridden-town.html: 4 chunks
# Prepared a-medical-miracle-is-period-blood-the-most-overlooked-opportunity-in-women-s-health.html: 7 chunks
# Prepared a-meeting-of-voices-flotillas-head-into-bel-m-ahead-of-cop30-climate-summit.html: 3 chunks
# Prepared a-mess-energy-suppliers-face-scramble-to-install-smart-meters-in-uk-homes.html: 3 chunks
# Prepared a-million-calls-an-hour-israel-relying-on-microsoft-cloud-for-expansive-surveillance-of-palestinians.html: 6 chunks
# Prepared a-million-us-taxpayers-to-get-pandemic-era-stimulus-checks-worth-up-to-1-400.html: 1 chunks
# Prepared a-minecraft-movie-review-building-block-game-franchise-spin-off-is-rollicking-if-exhausting-fun.html: 2 chunks
# Prepared a-model-of-the-transnational-artist-cuban-artist-wifredo-lam-gets-first-us-retrospective.html: 3 chunks
# Prepared a-moment-that-changed-me-i-thought-i-d-never-fit-in-in-rural-france-until-a-revelation-at-the-boulangerie.html: 2 chunks
# Prepared a-moment-that-changed-me-i-used-a-pseudonym-on-a-dating-app-and-started-exploring-my-sexuality.html: 2 chunks
# Prepared a-monumental-moment-for-circular-fashion-vintage-clothes-conquer-london.html: 2 chunks
# Prepared a-more-circular-bra-how-stephanie-devine-turned-an-underwear-gap-into-business-success.html: 3 chunks
# Prepared a-mythical-place-how-a-melbourne-sewage-farm-became-a-haven-for-300-species-of-birds.html: 4 chunks
# Prepared a-navajo-man-cries-out-for-water-on-a-pinnacle-in-utah-elliot-ross-s-best-photograph.html: 2 chunks
# Prepared a-neural-fossil-human-ears-try-to-move-when-listening-scientists-say.html: 2 chunks
# Prepared a-new-island-erupted-from-the-sea-can-it-show-us-how-nature-works-without-human-interference.html: 3 chunks
# Prepared a-new-kind-of-action-how-babes-with-blades-are-fighting-for-screen-space-for-women-of-colour.html: 2 chunks
# Prepared a-new-model-for-digital-media-what-karlie-kloss-s-acquisition-of-i-d-means.html: 3 chunks
# Prepared a-new-report-highlights-the-staggering-truth-about-wage-inequality-in-australia-here-s-what-we-need-to-do-better.html: 2 chunks
# Prepared a-new-room-for-a-doomed-loom-and-the-battle-to-save-australia-s-slowly-dying-crafts.html: 4 chunks
# Prepared a-new-soft-plastics-recycling-scheme-is-replacing-australia-s-failed-redcycle-will-it-mean-consumers-have-to-pay-more.html: 3 chunks
# Prepared a-new-space-to-play-in-can-vertical-dramas-save-the-uk-s-tv-sector.html: 4 chunks
# Prepared a-new-start-after-60-i-wanted-to-retire-from-farming-but-never-dreamed-i-would-become-an-artist.html: 2 chunks
# Prepared a-nobel-peace-prize-for-donald-trump-would-be-ludicrous.html: 1 chunks
# Prepared a-note-to-politicians-hoping-to-emulate-mamdani-s-social-media-strategy-without-the-right-policies-it-s-pointless.html: 2 chunks
# Prepared a-nuanced-approach-to-ageing-sex-and-gender.html: 2 chunks
# Prepared a-one-man-headline-machine-murdoch-tabloid-spins-ray-hadley-s-sprays-as-exclusive-news-stories.html: 4 chunks
# Prepared a-palestinian-chef-s-quest-to-preserve-his-heritage-one-dish-at-a-time-this-is-a-political-act.html: 3 chunks
# Prepared a-palette-unlike-anything-in-the-west-ben-okri-yinka-shonibare-and-more-on-how-nigerian-art-revived-britain-s-cultural-landscape.html: 7 chunks
# Prepared a-pandemic-level-shock-to-the-system-rfk-jr-s-old-environmental-group-weighs-epa-cuts.html: 3 chunks
# Prepared a-patriotic-education-hong-kong-schools-begin-rollout-of-xi-jinping-thought.html: 2 chunks
# Prepared a-perfect-boiled-egg-in-32-minutes-don-t-let-science-ruin-the-joyful-imperfection-of-home-cooking.html: 3 chunks
# Prepared a-perfect-coincidence-rare-red-lightning-captured-in-new-zealand-skies.html: 1 chunks
# Prepared a-perfect-symbiosis-planting-vines-and-other-ways-hot-cities-are-creating-cool-spaces.html: 2 chunks
# Prepared a-place-at-the-farmer-s-table-on-a-foodie-trip-to-trieste.html: 3 chunks
# Prepared a-plea-for-connection-gaza-musicians-perform-at-sydney-opera-house-as-cultural-institutions-destroyed-at-home.html: 2 chunks
# Prepared a-policy-that-benefited-the-richest-and-cost-the-uk-100bn-it-s-long-past-time-to-end-the-fuel-duty-freeze.html: 3 chunks
# Prepared a-predicted-deficit-will-get-the-headlines-but-remember-that-budgets-are-about-choices.html: 3 chunks
# Prepared a-professor-had-a-2-4m-grant-to-study-black-maternal-health-then-trump-was-elected.html: 4 chunks
# Prepared a-promising-practical-solution-sydney-s-new-schools-based-therapy-changes-how-teachers-and-parents-deal-with-bullying.html: 3 chunks
# Prepared a-proper-diagnosis-prof-lord-darzi-keyhole-pioneer-asked-to-unpick-nhs.html: 2 chunks
# Prepared a-prophetic-1934-novel-has-found-a-surprising-second-life-it-holds-lessons-for-us-all.html: 3 chunks
# Prepared a-proxy-for-america-s-culture-war-why-cracker-barrel-s-new-logo-sparked-ire-on-the-right.html: 3 chunks
# Prepared a-psychological-umbilical-cord-why-fiction-loves-difficult-mothers.html: 3 chunks
# Prepared a-punch-in-the-face-germany-s-dash-for-gas-raises-questions-over-climate-targets.html: 3 chunks
# Prepared a-race-against-time-what-now-for-thames-water-after-rescue-deal-collapses.html: 3 chunks
# Prepared a-radical-act-the-rich-history-behind-the-centuries-long-tradition-of-black-family-reunions.html: 4 chunks
# Prepared a-real-issue-video-game-developers-are-being-accused-of-using-ai-even-when-they-aren-t.html: 3 chunks
# Prepared a-real-mess-splits-emerge-in-labour-over-supreme-court-s-gender-ruling.html: 3 chunks
# Prepared a-real-wag-superman-gets-the-bleak-realities-of-dog-ownership-spot-on.html: 2 chunks
# Prepared a-real-wild-card-experts-struggle-to-predict-trump-s-stance-on-venezuela.html: 3 chunks
# Prepared a-reality-show-sent-12-virgins-to-an-island-to-learn-how-to-have-sex-the-result-was-weirdly-coy.html: 2 chunks
# Prepared a-relentless-destructive-energy-inside-the-trial-of-constance-marten-and-mark-gordon.html: 20 chunks
# Prepared a-relic-of-horny-hollywood-why-the-mummy-remains-a-classic-bisexual-awakening-movie.html: 2 chunks
# Prepared a-remarkable-ability-to-inspire-global-tributes-pour-in-for-jane-goodall.html: 3 chunks
# Prepared a-remote-spy-base-and-a-criminal-blockade-raise-questions-about-australia-s-complicity-in-gaza-war.html: 4 chunks
# Prepared a-report-tied-iowa-s-water-pollution-to-agriculture-then-the-money-to-promote-it-mysteriously-disappeared.html: 3 chunks
# Prepared a-rightwing-minister-told-sweden-to-get-tough-on-crime-until-his-own-son-was-caught-in-a-nazi-scandal.html: 3 chunks
# Prepared a-risky-bet-friedrich-merz-criticised-over-plan-to-lift-germany-s-debt-rules.html: 3 chunks
# Prepared a-risky-bet-texas-republicans-poised-to-redraw-congressional-map-on-trump-s-orders.html: 3 chunks
# Prepared a-robin-inside-her-small-dark-eye-a-quantum-entanglement.html: 2 chunks
# Prepared a-ruthless-agenda-charting-100-days-of-trump-s-onslaught-on-the-environment.html: 9 chunks
# Prepared a-scapegoating-racial-equality-expert-on-how-public-health-is-weaponized-against-immigrants.html: 3 chunks
# Prepared a-secret-garden-national-theatre-turns-roof-into-riot-of-colour-with-dye-plants.html: 2 chunks
# Prepared a-shooting-killed-their-student-now-two-california-teachers-are-educating-kids-about-gun-violence.html: 3 chunks
# Prepared a-short-history-of-british-architecture-by-simon-jenkins-review-doric-columns-and-grand-designs-the-greatest-hits.html: 2 chunks
# Prepared a-short-history-of-stupidity-by-stuart-jeffries-review-comfortably-dumb.html: 2 chunks
# Prepared a-shout-out-to-anger-management.html: 1 chunks
# Prepared a-silicon-valley-nudist-resort-is-on-sale-for-30m-but-will-its-new-owner-go-textile.html: 3 chunks
# Prepared a-single-incident-brought-sydney-s-train-network-to-a-standstill-again-here-s-why-it-keeps-happening.html: 3 chunks
# Prepared a-sisterhood-of-the-travelling-pants-but-with-belly-support-shorts-how-to-ethically-shop-and-share-maternity-clothes.html: 3 chunks
# Prepared a-slap-in-the-face-our-expert-panel-on-australia-s-2035-emissions-target.html: 5 chunks
# Prepared a-small-but-mighty-program-little-known-us-light-pollution-agency-threatened-by-trump-funding-cuts.html: 2 chunks
# Prepared a-social-media-ban-for-everyone-is-in-the-national-interest-not-just-kids-under-16.html: 3 chunks
# Prepared a-social-media-ban-won-t-keep-my-teenagers-safe-it-just-takes-away-the-place-they-love.html: 3 chunks
# Prepared a-soul-killer-what-s-behind-the-us-s-critical-veterinarian-shortage.html: 3 chunks
# Prepared a-south-park-halloween-latest-episode-destroys-trump-over-white-house-demolition.html: 2 chunks
# Prepared a-space-for-mourning-or-a-trauma-theme-park-dark-mofo-struggles-with-its-most-powerful-works.html: 4 chunks
# Prepared a-space-for-solace-stonehenge-show-explores-attraction-of-stone-circles.html: 2 chunks
# Prepared a-splintering-by-dur-e-aziz-amna-review-a-woman-s-ambitions-in-pakistan.html: 2 chunks
# Prepared a-sprawling-global-family-the-long-wave-turns-one.html: 2 chunks
# Prepared a-spree-change-from-berlin-to-oslo-europe-s-urban-swimmers-take-the-plunge.html: 5 chunks
# Prepared a-state-clean-up-may-be-the-best-bet-for-thames-water.html: 2 chunks
# Prepared a-stomach-of-steel-amateur-investors-ride-out-dips-amid-talk-of-an-ai-bubble.html: 4 chunks
# Prepared a-story-of-south-asian-art-review-banging-sculpture-marred-by-dreary-neighbours.html: 2 chunks
# Prepared a-structural-dependence-on-heavy-industry-can-south-korea-wean-itself-off-fossil-fuels.html: 5 chunks
# Prepared a-sydney-police-officer-confronted-a-mass-murderer-her-backup-was-a-carpenter-and-construction-worker-wielding-bollards.html: 4 chunks
# Prepared a-tale-of-two-suckers-donald-trump-s-plastic-straws-and-keir-starmer.html: 3 chunks
# Prepared a-third-of-outpatients-treated-for-wounds-at-msf-s-gaza-hospitals-in-2024-were-children-figures-show.html: 2 chunks
# Prepared a-third-of-people-in-england-believe-in-ghosts-survey-finds.html: 2 chunks
# Prepared a-third-of-school-staff-in-england-report-physical-underdevelopment-in-poor-students.html: 2 chunks
# Prepared a-third-of-the-arctic-s-vast-carbon-sink-now-a-source-of-emissions-study-reveals.html: 2 chunks
# Prepared a-third-term-for-trump-would-be-unconstitutional-here-s-why.html: 2 chunks
# Prepared a-timebomb-could-a-french-mine-full-of-waste-poison-the-drinking-water-of-millions.html: 4 chunks
# Prepared a-tiny-rhino-foetus-developed-by-ivf-jon-a-ju-rez-s-best-photograph.html: 3 chunks
# Prepared a-toast-to-grannies-and-good-manners.html: 1 chunks
# Prepared a-torrent-of-special-pleas-from-thames-water.html: 2 chunks
# Prepared a-tower-topped-with-a-pangolin-the-oxford-university-building-inspired-by-tolkien-and-the-pandemic.html: 4 chunks
# Prepared a-town-divided-how-cruise-tourism-tore-greenland-s-iceberg-capital-in-two.html: 2 chunks
# Prepared a-train-tour-of-europe-s-cool-northern-capitals-from-london-to-vilnius-via-berlin-and-warsaw.html: 4 chunks
# Prepared a-tree-a-minute-for-24-hours-the-young-victorian-forest-that-was-planted-in-a-day.html: 2 chunks
# Prepared a-trick-of-the-mind-by-daniel-yon-review-explaining-psychology-s-most-important-theory.html: 2 chunks
# Prepared a-triumph-london-s-19bn-elizabeth-line-is-named-best-new-architecture-in-britain.html: 3 chunks
# Prepared a-trojan-horse-how-toxic-sewage-sludge-became-a-threat-to-the-future-of-british-farming.html: 3 chunks
# Prepared a-truce-that-is-not-peace-by-miriam-toews-review-a-searingly-intimate-memoir.html: 3 chunks
# Prepared a-truly-authentic-experience-that-benefits-everyone-readers-favourite-community-travel-experiences.html: 2 chunks
# Prepared a-trump-ira-for-kids-it-s-worth-a-bit-of-money-but-here-are-better-options.html: 2 chunks
# Prepared a-trump-visit-a-creaking-coalition-and-a-cost-of-living-crisis-japan-s-new-pm-needs-a-fast-start.html: 2 chunks
# Prepared a-uk-headline-wealth-tax-it-may-be-simpler-to-put-up-existing-taxes.html: 2 chunks
# Prepared a-us-haven-for-refugees-was-divided-over-trump-now-immigration-crackdown-has-left-a-community-breaking.html: 4 chunks
# Prepared a-us-senator-s-x-posts-after-the-minnesota-shootings-were-horrific-and-predictable.html: 3 chunks
# Prepared a-vehicle-for-love-the-public-art-project-highlighting-immigrants-contributions-to-us-cities.html: 3 chunks
# Prepared a-venue-like-this-doesn-t-exist-elsewhere-inside-the-colossal-arena-built-for-the-hunger-games.html: 3 chunks
# Prepared a-very-camp-environment-why-alan-turing-fatefully-told-police-he-was-gay.html: 3 chunks
# Prepared a-victory-for-gen-z-inside-the-24-october-guardian-weekly.html: 2 chunks
# Prepared a-video-a-pastor-and-a-tense-meeting-timeline-of-charlie-kirk-suspect-s-arrest.html: 3 chunks
# Prepared a-vision-of-sport-in-2050-robot-leagues-chips-in-brains-and-players-in-their-50s.html: 3 chunks
# Prepared a-want-in-her-review-daughter-s-searing-portrait-of-family-addiction-and-mental-illness.html: 1 chunks
# Prepared a-war-on-children-as-us-changes-covid-vaccine-rules-parents-of-trial-volunteers-push-back.html: 3 chunks
# Prepared a-week-of-grief-is-a-reminder-to-reflect-on-the-magnificent-triviality-of-sport.html: 3 chunks
# Prepared a-week-of-war-that-left-iran-stunned-and-bloodied.html: 4 chunks
# Prepared a-whole-spectrum-of-hatred-women-face-increased-violence-in-milei-s-argentina-as-rights-are-eroded.html: 3 chunks
# Prepared a-wild-and-orgasmic-ride-basic-instinct-set-for-anti-woke-reboot.html: 2 chunks
# Prepared a-wild-walk-along-spain-s-empty-coast-where-the-desert-meets-the-sea.html: 3 chunks
# Prepared a-win-win-for-farmers-how-flooding-fields-in-north-west-england-could-boost-crops.html: 3 chunks
# Prepared a-world-cup-preying-on-fomo-fifa-s-2026-ticket-scheme-is-a-late-capitalist-hellscape.html: 4 chunks
# Prepared a-world-detached-from-struggles-of-urban-life-a-rare-exhibition-of-renoir-drawings.html: 4 chunks
# Prepared a-year-after-devastating-trump-loss-have-the-democrats-begun-to-find-their-way-back.html: 4 chunks
# Prepared a-year-after-trump-won-why-won-t-democrats-change-their-playbook.html: 6 chunks
# Prepared a-year-ago-i-was-on-a-mobility-scooter-emma-raducanu-happy-to-be-injury-free.html: 2 chunks
# Prepared a-year-of-two-halves-how-global-financial-markets-fared-in-2024.html: 3 chunks
# Prepared a-year-with-the-seals-review-what-to-know-about-the-elusive-sea-creature.html: 2 chunks
# Prepared a-yorkshire-pudding-like-a-dishcloth-how-did-british-pub-food-get-so-grim.html: 6 chunks
# Prepared aaron-sorkin-s-the-social-network-sequel-officially-in-development.html: 1 chunks
# Prepared abandoned-infrastructure-one-of-the-biggest-polluters-in-the-world-report.html: 2 chunks
# Prepared abandoned-queensland-coal-borehole-found-to-be-emitting-10-000-cars-worth-of-greenhouse-gas.html: 2 chunks
# Prepared abandoned-van-found-in-search-for-missing-german-backpacker-carolina-wilga-in-remote-wa.html: 1 chunks
# Prepared abandoning-ukraine-means-infinitely-higher-long-term-security-costs-mi6-chief-says.html: 2 chunks
# Prepared abbas-says-hamas-must-surrender-their-weapons-as-it-happened.html: 25 chunks
# Prepared abbott-says-dumped-frontbencher-will-be-a-big-loss-as-it-happened.html: 28 chunks
# Prepared abc-and-sbs-gender-pay-gaps-revealed-as-public-sector-wage-data-released-for-the-first-time.html: 3 chunks
# Prepared abc-executive-who-sacked-antoinette-lattouf-paid-836-000-for-eight-month-employment-annual-report-shows.html: 2 chunks
# Prepared abc-news-suspends-journalist-who-called-trump-and-adviser-world-class-haters.html: 2 chunks
# Prepared abc-not-banned-from-trump-press-conferences-managing-director-says-as-it-happened.html: 34 chunks
# Prepared abc-to-review-editorial-policies-after-investigation-finds-gunshots-inadvertently-added-to-afghanistan-footage.html: 2 chunks
# Prepared abject-horror-the-troubling-history-of-paedophile-hunting-tv-shows.html: 4 chunks
# Prepared ablution-pollution-minimise-your-hygiene-carbon-footprint-with-some-simple-regime-tweaks.html: 2 chunks
# Prepared abnormal-art-is-the-only-good-art-how-fl-vio-de-carvalho-sparked-a-brazilian-revolution.html: 2 chunks
# Prepared abnormally-hot-days-may-hit-australia-s-south-east-after-rare-sudden-warming-over-antarctica.html: 1 chunks
# Prepared abolishing-stamp-duty-won-t-solve-britain-s-housing-crisis-but-this-radical-property-tax-just-might.html: 3 chunks
# Prepared abortion-has-come-grudgingly-to-northern-ireland-in-the-wake-of-coronavirus.html: 2 chunks
# Prepared abortion-laws-in-england-and-wales-face-biggest-shake-up-in-nearly-60-years.html: 2 chunks
# Prepared abortion-pill-providers-targeted-by-new-texas-law-refuse-anticipatory-obedience.html: 2 chunks
# Prepared abortion-pill-ru486-to-be-available-to-australian-women-over-the-phone.html: 2 chunks
# Prepared abortion-providers-on-two-years-of-texas-ban-we-re-living-in-a-devastating-reality.html: 7 chunks
# Prepared abortion-without-the-clinic-on-offer-with-revolutionary-new-us-program.html: 5 chunks
# Prepared abortions-in-the-us-are-on-the-rise-three-years-after-roe-v-wade-was-overturned.html: 2 chunks
# Prepared about-1bn-in-car-loan-compensation-at-risk-because-data-deleted-lawyers-warn.html: 2 chunks
# Prepared about-3m-australians-affected-by-unlawful-centrelink-debt-calculation-to-be-eligible-for-up-to-600-compensation.html: 2 chunks
# Prepared about-australian-climate-and-environment-in-focus.html: 1 chunks
# Prepared above-the-knee-review-man-struggles-with-body-integrity-dysmorphia-in-gory-amputation-horror.html: 1 chunks
# Prepared abuse-of-migrants-rampant-at-louisiana-ice-centers-report-finds.html: 3 chunks
# Prepared abuse-of-suspected-migrants-not-an-innocent-mistake-says-uk-equality-campaigner.html: 2 chunks
# Prepared academic-axed-from-labour-conference-panel-for-criticising-energy-policy.html: 2 chunks
# Prepared academic-freedom-in-the-us-is-under-threat-universities-of-the-world-unite.html: 2 chunks
# Prepared academics-say-their-net-zero-costing-is-being-misrepresented-after-nationals-repeat-9tn-claim.html: 2 chunks
# Prepared accelerating-women-businesses-closing-the-gender-gap.html: 2 chunks
# Prepared ackroyd-harvey-the-art-of-activism-review-culture-and-politics-collide-in-film-of-eco-artist-double-act.html: 1 chunks
# Prepared across-cultures-and-centuries-aristotle-and-confucius-agree-virtue-is-good-in-moderation.html: 2 chunks
# Prepared across-europe-the-financial-sector-has-pushed-up-house-prices-it-s-a-political-timebomb.html: 4 chunks
# Prepared act-moves-to-protect-dingoes-after-genetic-study-into-animals-in-namadgi-national-park.html: 2 chunks
# Prepared acting-head-of-us-employment-rights-agency-failing-to-protect-trans-and-nonbinary-workers-democrats-say.html: 1 chunks
# Prepared action-needed-on-plastic-additives-linked-to-sperm-decline-experts-warn.html: 2 chunks
# Prepared activists-blend-science-and-folklore-as-they-try-to-revive-somerset-s-eel-population.html: 2 chunks
# Prepared activists-call-for-state-of-emergency-in-nigeria-over-gender-based-violence.html: 2 chunks
# Prepared activists-in-netherlands-protest-on-roof-of-microsoft-site-storing-israeli-military-data.html: 2 chunks
# Prepared activists-say-they-have-proof-ministers-tried-to-influence-police-over-israeli-arms-firm-protests.html: 2 chunks
# Prepared activities-we-should-bake-into-schoolchildren-s-education.html: 1 chunks
# Prepared actor-dirk-bogarde-was-disturbed-by-kgb-sting-warning-declassified-files-reveal.html: 1 chunks
# Prepared actor-june-lockhart-of-lost-in-space-and-lassie-fame-dies-aged-100.html: 1 chunks
# Prepared actor-robert-aramayo-like-anybody-who-hasn-t-had-the-education-i-thought-tourette-syndrome-was-all-about-swearing.html: 4 chunks
# Prepared actors-and-directors-pledge-not-to-work-with-israeli-film-groups-implicated-in-genocide.html: 3 chunks
# Prepared actors-trained-during-pandemic-lack-vocal-power-and-range-says-rsc-leader.html: 2 chunks
# Prepared adam-bandt-says-greens-hitting-a-nerve-as-conservative-lobby-group-takes-aim.html: 3 chunks
# Prepared adani-claims-its-export-program-helps-contribute-to-sustainable-energy-but-experts-say-that-s-wilful-disinformation.html: 2 chunks
# Prepared adani-denies-claims-it-sold-below-market-coal-leading-to-queensland-missing-out-on-hundreds-of-millions-in-royalties.html: 2 chunks
# Prepared adani-names-two-dead-australian-war-veterans-in-documents-alleging-protest-conspiracy-against-it.html: 2 chunks
# Prepared add-to-playlist-c-line-dessberg-s-harp-evokes-hollywood-and-home-plus-the-week-s-best-new-tracks.html: 2 chunks
# Prepared adhd-prescriptions-in-england-have-risen-by-18-each-year-since-pandemic.html: 2 chunks
# Prepared adolescence-s-message-has-echoed-around-the-world-but-a-social-media-ban-is-the-wrong-move.html: 3 chunks
# Prepared adolescence-star-stephen-graham-launches-global-project-asking-fathers-to-write-to-their-sons.html: 2 chunks
# Prepared adolescence-writer-jack-thorne-backs-smartphone-free-childhood-group.html: 2 chunks
# Prepared adult-education-should-be-for-life-not-just-a-job.html: 2 chunks
# Prepared adults-in-great-britain-now-spending-more-time-on-mobiles-than-watching-tv.html: 2 chunks
# Prepared advantage-china-plus-saving-british-steel.html: 2 chunks
# Prepared advergames-how-games-platform-roblox-became-a-corporate-marketing-playground.html: 5 chunks
# Prepared advertising-giant-wpp-cuts-diversity-references-from-annual-report.html: 1 chunks
# Prepared adviser-to-uk-minister-claimed-ai-firms-would-never-have-to-compensate-creatives.html: 2 chunks
# Prepared advocates-raise-alarm-over-pfas-pollution-from-datacenters-amid-ai-boom.html: 3 chunks
# Prepared afd-politician-s-former-aide-convicted-of-spying-for-china.html: 2 chunks
# Prepared affinity-education-childcare-worker-facing-multiple-child-sexual-abuse-charges.html: 1 chunks
# Prepared afghanistan-blind-without-phones-and-internet-on-second-day-of-telecoms-blackout.html: 2 chunks
# Prepared afghanistan-risks-polio-outbreak-as-taliban-restricts-women-from-delivering-vaccines.html: 2 chunks
# Prepared afl-2025-predicted-ladder-part-one-carlton-bring-the-noise-but-fail-to-convince.html: 4 chunks
# Prepared afl-2025-predicted-ladder-part-two-creaking-collingwood-s-final-crack-at-a-flag.html: 4 chunks
# Prepared afl-finals-why-every-finalist-can-and-can-t-win-the-2025-premiership.html: 5 chunks
# Prepared afl-grand-final-2025-ultimate-guide-to-the-flag-decider-between-geelong-and-brisbane.html: 3 chunks
# Prepared afl-s-tasmania-expansion-on-a-knife-edge-amid-state-political-uncertainty.html: 1 chunks
# Prepared afl-urged-to-go-beyond-mental-health-round-with-player-voices-to-tackle-stigma.html: 2 chunks
# Prepared afp-developing-ai-tool-to-decode-gen-z-slang-amid-warning-about-crimefluencers-hunting-girls.html: 2 chunks
# Prepared africa-s-children-20-years-on-what-happened-to-the-millennium-babies.html: 6 chunks
# Prepared africa-s-small-scale-revolution-against-big-agriculture-five-farmers-talk-greener-better-food.html: 3 chunks
# Prepared africa-should-not-be-too-quick-to-embrace-the-fourth-industrial-revolution.html: 3 chunks
# Prepared africa-to-finally-receive-first-batch-of-vaccines-for-deadly-mpox-virus.html: 1 chunks
# Prepared african-diplomats-urge-uk-government-to-back-bill-to-speed-up-debt-restructurings.html: 2 chunks
# Prepared african-football-s-general-secretary-accused-of-creating-toxic-culture-of-fear.html: 3 chunks
# Prepared african-history-students-awarded-compensation-after-master-s-axed.html: 2 chunks
# Prepared african-nations-hit-by-mpox-still-waiting-for-vaccines-despite-promises-by-the-west.html: 2 chunks
# Prepared africans-who-fought-in-the-second-world-war-deserve-fair-recompense.html: 1 chunks
# Prepared after-berlin-angela-merkel-s-open-door-to-migrants-might-slam-shut.html: 2 chunks
# Prepared after-call-to-overhaul-diagnosis-of-obesity-how-can-you-tell-if-your-weight-is-a-problem.html: 3 chunks
# Prepared after-canada-and-australia-could-donald-trump-really-be-the-saviour-of-centre-left-politics.html: 3 chunks
# Prepared after-chaos-of-the-yoon-era-south-korea-prepares-to-pick-a-new-president.html: 3 chunks
# Prepared after-disability-benefits-is-labour-really-about-to-target-the-educational-rights-of-special-needs-children.html: 4 chunks
# Prepared after-hundreds-of-complaints-eharmony-s-auto-renewal-subscription-case-begins-in-australian-federal-court.html: 2 chunks
# Prepared after-losing-homes-and-businesses-la-wildfire-victims-face-a-hurdle-to-rebuilding-trump-s-tariffs.html: 3 chunks
# Prepared after-my-car-was-damaged-in-a-tesco-car-wash-it-has-washed-its-hands-of-my-complaint.html: 1 chunks
# Prepared after-pivotal-2020-voter-drive-us-union-braces-for-another-fight-against-trump.html: 3 chunks
# Prepared after-school-carer-charged-with-producing-child-abuse-material-at-six-facilities-across-northern-sydney.html: 3 chunks
# Prepared after-the-ceasefire-inside-the-17-october-guardian-weekly.html: 2 chunks
# Prepared after-the-far-right-s-march-on-our-streets-londoners-must-show-trump-we-reject-his-politics-of-fear.html: 2 chunks
# Prepared after-the-ftx-crash-here-s-what-you-need-to-know-the-crypto-bubble-is-already-bursting.html: 2 chunks
# Prepared after-the-joy-of-seeing-carney-beat-his-trump-lite-rival-reality-has-bitten-canada-is-an-anxious-divided-nation.html: 3 chunks
# Prepared after-the-mushroom-murders-media-circus-will-dark-tourism-be-next-for-a-small-victorian-town.html: 3 chunks
# Prepared after-the-spike-by-dean-spears-and-michael-geruso-review-the-truth-about-population.html: 2 chunks
# Prepared after-war-of-words-at-lord-s-england-stick-to-manchester-masterplan.html: 3 chunks
# Prepared afternoon-update-475m-win-for-robodebt-victims-factchecking-mass-migration-claims-and-tony-abbott-joins-substack.html: 2 chunks
# Prepared afternoon-update-alp-s-social-media-backfire-queensland-signs-education-deal-and-kindness-at-the-airport-baggage-carousel.html: 2 chunks
# Prepared afternoon-update-another-optus-triple-zero-outage-skydivers-leap-from-doomed-plane-and-bad-bunny-to-headline-super-bowl.html: 2 chunks
# Prepared afternoon-update-australia-facing-500m-chevron-cleaning-bill-obama-breaks-silence-on-trump-and-the-blowback-against-office-air.html: 2 chunks
# Prepared afternoon-update-australia-lobbied-uk-to-avoid-indigenous-leaders-in-1999-sa-premier-calls-algae-natural-disaster-and-the-case-against-coffee-snobs.html: 2 chunks
# Prepared afternoon-update-australia-s-climate-breakdown-risks-laid-bare-anz-slapped-with-record-fine-and-adolescence-wins-big-at-emmys.html: 2 chunks
# Prepared afternoon-update-australia-s-pandemic-response-grossly-inadequate-wong-condemns-israel-s-unrwa-ban-and-new-wallabies-jersey-revealed.html: 2 chunks
# Prepared afternoon-update-australia-says-iran-orchestrated-antisemitic-attacks-police-killed-in-porepunkah-and-a-tribute-to-country-footy.html: 2 chunks
# Prepared afternoon-update-australian-charged-in-us-over-alleged-role-in-ponzi-scheme-surreal-sydney-shark-rescue-and-mp-criticises-nine-for-sexist-photo-edit.html: 3 chunks
# Prepared afternoon-update-concerns-over-trump-pharma-threat-recipetin-eats-cook-speaks-after-mushroom-trial-and-a-tiny-four-legged-hero.html: 2 chunks
# Prepared afternoon-update-dozens-missing-after-ferry-sinks-off-bali-creative-australia-chair-apologises-to-sabsabi-and-rise-of-robot-narrators.html: 2 chunks
# Prepared afternoon-update-dutton-unveils-nuclear-plan-without-costs-bird-flu-detected-in-nsw-and-children-dying-from-air-pollution.html: 2 chunks
# Prepared afternoon-update-election-2025-dutton-says-he-believes-in-climate-change-price-accuses-media-of-maga-pile-on-and-a-human-book-chain.html: 3 chunks
# Prepared afternoon-update-election-2025-greens-want-1-of-budget-for-environment-dutton-ready-for-fight-with-trump-and-val-kilmer-dies-aged-65.html: 2 chunks
# Prepared afternoon-update-election-edition-campaign-is-on-dutton-s-gas-plan-questioned-and-a-shoe-runs-into-trouble.html: 2 chunks
# Prepared afternoon-update-energy-australia-apologises-to-400-000-customers-gina-rinehart-criticises-media-gloating-and-the-who-drummer-fired-for-second-time-in-a-month.html: 2 chunks
# Prepared afternoon-update-giuffre-family-declare-victory-over-andrew-disgraced-mp-gareth-ward-sentenced-and-nasa-v-kim-kardashian.html: 1 chunks
# Prepared afternoon-update-heatwave-and-wild-winds-grip-nation-palestinians-with-australian-visas-trapped-in-gaza-and-hollywood-a-listers-flop.html: 1 chunks
# Prepared afternoon-update-likely-source-of-poo-balls-revealed-video-emerges-of-louvre-heist-and-our-nerdiest-quiz.html: 2 chunks
# Prepared afternoon-update-more-backlash-over-biennale-artist-axing-nz-tourism-campaign-ridiculed-and-what-it-s-like-living-with-ocd.html: 1 chunks
# Prepared afternoon-update-national-register-for-childcare-workers-sunscreen-brand-pulled-from-shelves-and-readers-book-week-costumes.html: 2 chunks
# Prepared afternoon-update-pm-in-us-for-trump-meeting-october-heat-records-set-to-tumble-and-a-break-up-note-to-america.html: 1 chunks
# Prepared afternoon-update-poland-shoots-down-russian-drones-unrepentant-nampijinpa-price-won-t-back-ley-and-an-australian-take-on-the-iliad.html: 2 chunks
# Prepared afternoon-update-police-arrest-alleged-kill-team-in-sydney-price-calls-out-liberal-leaks-and-an-ode-to-horny-hollywood.html: 2 chunks
# Prepared afternoon-update-pro-palestine-march-pushback-australia-s-one-shot-at-clean-energy-and-the-afl-s-most-sought-after-signature.html: 1 chunks
# Prepared afternoon-update-qantas-fined-90m-far-right-israeli-mp-barred-from-australia-and-margaret-pomeranz-remembers-david-stratton.html: 2 chunks
# Prepared afternoon-update-rba-keeps-cash-rate-on-hold-female-jockey-s-melbourne-cup-win-and-the-forgotten-republic-of-transnistria.html: 2 chunks
# Prepared afternoon-update-rba-s-surprise-decision-how-world-reported-mushroom-verdict-and-valerie-the-dachshund-s-new-job.html: 2 chunks
# Prepared afternoon-update-salmon-farming-to-continue-in-tasmania-stratton-dies-aged-85-and-the-world-s-most-divisive-shoes.html: 2 chunks
# Prepared afternoon-update-sexual-abuse-claim-farming-arrests-steggall-s-corridor-ambush-over-electoral-laws-and-fashion-s-football-shirts-obsession.html: 1 chunks
# Prepared afternoon-update-troubled-waters-for-aukus-agency-bitcoin-reaches-new-high-and-australia-s-spotify-wrapped.html: 2 chunks
# Prepared afternoon-update-trump-and-musk-s-spectacular-blowup-australian-navy-ship-accidentally-blocks-nz-wifi-and-embracing-a-gift-economy.html: 2 chunks
# Prepared afternoon-update-trump-s-truth-social-posting-frenzy-hanson-speaks-at-mar-a-lago-and-hitching-a-ride-on-a-whale.html: 1 chunks
# Prepared afternoon-update-universities-targeted-under-antisemitism-envoy-plan-teen-surfer-found-on-remote-island-and-a-human-book-chain.html: 2 chunks
# Prepared aftershocks-expected-after-south-east-queensland-shaken-by-5-6-magnitude-earthquake.html: 2 chunks
# Prepared again-and-again-we-are-shocked-by-the-treatment-of-learning-disabled-people-yet-we-never-learn-from-the-past.html: 3 chunks
# Prepared age-and-migration-influence-bird-groups-song-repertoires-study-finds.html: 2 chunks
# Prepared age-assurance-trial-stakeholders-frozen-out-victorian-liberal-leader-s-impromptu-press-conference-and-tarantino-s-favourite-tarantino.html: 2 chunks
# Prepared age-gender-education-the-house-of-lords-in-charts.html: 3 chunks
# Prepared age-of-the-panzootic-scientists-warn-of-more-devastating-diseases-jumping-between-species.html: 3 chunks
# Prepared age-verification-is-coming-to-search-engines-in-australia-with-huge-implications-for-privacy-and-inclusion.html: 3 chunks
# Prepared ageing-revolutionary-guardiola-is-waging-war-on-his-own-tactical-orthodoxies.html: 3 chunks
# Prepared agency-in-charge-of-australia-s-368bn-submarine-program-faces-staff-morale-crisis.html: 3 chunks
# Prepared agency-overseeing-368bn-aukus-deal-in-morale-crisis-paid-consultancy-9-5m-for-management-advice.html: 2 chunks
# Prepared aggressive-hackers-of-uk-retailers-are-now-targeting-us-stores-says-google.html: 1 chunks
# Prepared agriculture-secretary-accused-of-unlawfully-refusing-to-use-emergency-fund-to-prevent-food-stamp-disruption-as-it-happened.html: 11 chunks
# Prepared agriculture-the-spiritual-sound-review-unabashedly-gorgeous-noise-from-ecstatic-black-metal-band.html: 1 chunks
# Prepared agyemang-injury-to-defensive-frailty-key-takeaways-as-england-start-world-cup-buildup.html: 2 chunks
# Prepared ai-avatar-generator-synthesia-does-video-footage-deal-with-shutterstock.html: 2 chunks
# ...
# Prepared y2k-fashion-and-vinyl-grooves-meet-abidjan-s-young-guardians-of-nostalgia.html: 2 chunks
# Prepared yari-club-london-wc2-i-didn-t-expect-the-robot-chef-to-be-simply-a-no-frills-kitchen-gadget-restaurant-review.html: 2 chunks
# Prepared yarning-circles-murals-and-athletics-schools-prove-there-s-more-to-a-good-education-than-naplan-results.html: 2 chunks
# Prepared yellow-weather-warnings-for-july-thunderstorms-that-failed-to-materialise.html: 1 chunks
# Prepared yes-small-businesses-are-suffering-but-some-are-helping-to-fight-coronavirus.html: 2 chunks
# Prepared yes-the-stock-markets-are-in-turmoil-but-it-really-is-a-good-idea-to-invest.html: 3 chunks
# Prepared yes-we-ve-been-to-the-moon-before-nasa-rebuffs-kim-kardashian-conspiracy-theory.html: 2 chunks
# Prepared ynys-enlli-off-welsh-coast-designated-as-a-dark-sky-sanctuary.html: 2 chunks
# Prepared yoga-with-adriene-is-now-a-direct-substitute-for-things-i-used-to-do-outside-exercising-socialising-even-therapy.html: 2 chunks
# Prepared yorkshire-water-announces-hosepipe-ban-after-driest-spring-in-132-years.html: 2 chunks
# Prepared yotam-ottolenghi-s-recipe-for-lemon-and-sage-roasted-almonds.html: 1 chunks
# Prepared you-be-the-judge-should-my-boyfriend-get-rid-of-his-laundry-basket.html: 3 chunks
# Prepared you-be-the-judge-should-my-boyfriend-stop-drinking-from-a-water-bladder-during-sex.html: 3 chunks
# Prepared you-be-the-judge-should-my-girlfriend-stop-picking-up-other-people-s-litter.html: 3 chunks
# Prepared you-be-the-judge-should-my-partner-stop-hankering-after-salt-and-pepper-shakers.html: 3 chunks
# Prepared you-be-the-judge-should-my-partner-use-a-co-working-space-so-i-can-have-our-flat-to-myself.html: 3 chunks
# Prepared you-britons-go-to-the-pub-we-go-to-the-swimming-pool-the-european-health-habits-worth-adopting.html: 7 chunks
# Prepared you-can-be-an-ethical-hacker-not-a-criminal-one-the-initiative-guiding-young-gamers-into-cybersecurity.html: 3 chunks
# Prepared you-can-do-hard-things-the-young-cycling-enthusiasts-reclaiming-the-streets-of-johannesburg.html: 2 chunks
# Prepared you-can-t-keep-coming-for-agriculture-farmers-prepare-to-protest-over-bitter-budget-harvest.html: 2 chunks
# Prepared you-can-t-pause-the-internet-social-media-creators-hit-by-burnout.html: 3 chunks
# Prepared you-can-t-shoot-climate-change-richard-seymour-on-how-far-right-exploits-environmental-crisis.html: 5 chunks
# Prepared you-cannot-undo-a-wrongful-execution-push-to-halt-killing-of-texas-man-in-shaken-baby-case.html: 4 chunks
# Prepared you-could-drink-from-that-pond-the-city-digging-for-a-solution-to-toxic-runoff.html: 3 chunks
# Prepared you-definitely-felt-disposable-models-one-27-one-62-discuss-botox-weight-loss-creativity-and-the-threat-of-ai.html: 5 chunks
# Prepared you-don-t-get-to-aim-big-when-you-are-somewhere-small-a-teenager-s-fight-to-end-single-use-plastics-on-her-scottish-island.html: 2 chunks
# Prepared you-don-t-need-one-until-you-do-10-safety-essentials-cyclists-won-t-leave-home-without.html: 3 chunks
# Prepared you-feel-useful-to-society-italy-s-busybody-pensioners-go-professional.html: 2 chunks
# Prepared you-get-sucked-in-crypto-scam-victims-on-how-they-lost-up-to-162-000.html: 4 chunks
# Prepared you-got-some-pants-on-officer-video-from-detroit-virtual-court-hearing-goes-viral.html: 1 chunks
# Prepared you-have-the-experience-of-a-sick-person-but-it-s-not-yours-leeds-art-installation-explores-being-a-carer.html: 2 chunks
# Prepared you-have-to-find-your-own-recipe-dutch-suburb-where-residents-must-grow-food-on-at-least-half-of-their-property.html: 3 chunks
# Prepared you-have-to-ruffle-feathers-a-history-of-controversial-jeans-adverts.html: 2 chunks
# Prepared you-have-unmet-needs-the-psychology-behind-australia-s-love-affair-with-big-cars.html: 4 chunks
# Prepared you-just-believe-why-willy-wonka-the-chocolate-factory-is-my-feelgood-movie.html: 2 chunks
# Prepared you-just-hope-for-the-best-rarely-seen-froglets-the-length-of-a-grain-of-rice-released-into-small-patch-of-victorian-wilds.html: 2 chunks
# Prepared you-ll-never-save-the-world-with-art-but-it-will-help-you-survive-artist-calls-on-ukraine-to-promote-its-culture.html: 3 chunks
# Prepared you-need-solidarity-and-consistency-pedro-s-nchez-on-the-eu-trump-and-fighting-the-far-right.html: 3 chunks
# Prepared you-open-the-fridge-nothing-renewed-threat-of-us-hunger-as-trump-seeks-to-cut-food-aid.html: 5 chunks
# Prepared you-re-either-poor-or-rich-the-argentinians-struggling-under-milei-s-chainsaw-austerity.html: 3 chunks
# Prepared you-re-going-about-your-day-and-suddenly-see-a-little-godzilla-bangkok-reckons-with-a-giant-lizard-boom.html: 3 chunks
# Prepared you-re-that-guy-on-tiktok-the-vice-chancellor-who-reimagined-how-a-sydney-university-could-work.html: 2 chunks
# Prepared you-re-the-only-port-of-call-for-400-hospital-patients-which-is-absurd-matthew-hutchinson-on-the-perils-of-life-as-an-nhs-doctor.html: 6 chunks
# Prepared you-should-act-your-age-at-least-when-it-comes-to-exercise-here-s-why.html: 4 chunks
# Prepared you-should-be-partying-when-you-write-party-music-pop-hedonists-confidence-man-on-their-super-sweaty-new-album.html: 2 chunks
# Prepared you-sold-it-now-recycle-it-the-protesters-mailing-worn-out-clothes-to-the-shops-they-bought-them-from.html: 5 chunks
# Prepared young-adult-books-roundup-review.html: 2 chunks
# Prepared young-and-old-how-the-covid-pandemic-has-affected-every-uk-generation.html: 7 chunks
# Prepared young-australians-have-much-higher-student-debt-than-generations-before-them-data-shows.html: 1 chunks
# Prepared young-british-woman-held-on-drug-charges-in-sri-lanka-could-be-linked-to-culley-case.html: 3 chunks
# Prepared young-climate-activist-tells-greenpeace-to-drop-old-fashioned-anti-nuclear-stance.html: 2 chunks
# Prepared young-climate-activists-in-court-aim-to-stop-trump-s-pro-fossil-fuel-executive-orders.html: 2 chunks
# Prepared young-climate-activists-in-wisconsin-sue-state-over-pro-fossil-fuel-policies.html: 3 chunks
# Prepared young-country-diary-the-foxes-and-i-have-been-watching-each-other-closely.html: 1 chunks
# Prepared young-educated-and-knee-deep-in-rubbish-the-recyclers-cleaning-up-in-cairo-s-garbage-city.html: 3 chunks
# Prepared young-first-time-buyers-forced-into-nature-deserts-england-data-shows.html: 2 chunks
# Prepared young-men-in-uk-more-likely-than-women-to-live-with-parents.html: 1 chunks
# Prepared young-people-are-biggest-victims-of-uk-s-fragile-jobs-market.html: 2 chunks
# Prepared young-people-in-england-s-coastal-towns-three-times-more-likely-to-have-a-mental-health-condition.html: 3 chunks
# Prepared young-researchers-need-greater-access-to-britain-s-rich-archives-says-curator.html: 2 chunks
# Prepared young-tories-are-fed-up-the-students-switching-to-reform-in-big-numbers.html: 2 chunks
# Prepared young-vape-users-three-times-as-likely-to-start-smoking-study-finds.html: 2 chunks
# Prepared your-basis-to-live-is-checked-at-each-and-every-step-india-s-id-system-divides-opinion.html: 3 chunks
# Prepared your-best-comments-on-the-guardian-today.html: 3 chunks
# Prepared your-blood-runs-cold-the-anguish-parents-feel-after-a-daycare-worker-commits-a-sexual-offence-against-a-child.html: 5 chunks
# Prepared your-fat-friend-review-big-hearted-portrait-of-author-podcaster-and-activist-aubrey-gordon.html: 1 chunks
# Prepared your-guardian-sport-weekend-champions-league-final-french-open-and-spanish-gp.html: 2 chunks
# Prepared your-guardian-sport-weekend-club-world-cup-last-16-f1-austrian-gp-and-more.html: 3 chunks
# Prepared your-guardian-sport-weekend-club-world-cup-us-open-golf-tennis-and-rugby-finals.html: 2 chunks
# Prepared your-guardian-sport-weekend-england-v-fiji-f1-heating-up-and-premier-league.html: 5 chunks
# Prepared your-guardian-sport-weekend-england-v-india-club-world-cup-tennis-and-nba.html: 3 chunks
# Prepared your-guardian-sport-weekend-england-v-india-f1-in-hungary-and-women-s-open.html: 3 chunks
# Prepared your-guardian-sport-weekend-euro-2025-final-tour-de-france-and-f1-at-spa.html: 3 chunks
# Prepared your-guardian-sport-weekend-euro-2025-wimbledon-tour-de-france-and-much-more.html: 4 chunks
# Prepared your-guardian-sport-weekend-fa-cup-finals-f1-and-us-pga-championship-golf.html: 4 chunks
# Prepared your-guardian-sport-weekend-football-world-snooker-finale-and-f1-in-miami.html: 4 chunks
# Prepared your-guardian-sport-weekend-french-open-finals-football-cricket-and-much-more.html: 3 chunks
# Prepared your-guardian-sport-weekend-liverpool-on-verge-fa-cup-semis-women-s-six-nations-finale-and-london-marathon.html: 3 chunks
# Prepared your-guardian-sport-weekend-liverpool-v-arsenal-women-s-rugby-world-cup-and-more.html: 4 chunks
# Prepared your-guardian-sport-weekend-lord-s-test-wimbledon-finals-euro-2025-tour-de-france-and-much-more.html: 4 chunks
# Prepared your-guardian-sport-weekend-premier-league-returns-f1-in-the-us-and-world-cup-cricket.html: 5 chunks
# Prepared your-guardian-sport-weekend-premier-league-rugby-championship-and-more.html: 3 chunks
# Prepared your-guardian-sport-weekend-premier-league-wcl-final-monaco-gp-and-french-open.html: 4 chunks
# Prepared your-guardian-sport-weekend-prix-de-l-arc-de-triomphe-nfl-and-more.html: 4 chunks
# Prepared your-guardian-sport-weekend-rugby-league-ashes-lionesses-v-brazil-and-f1-s-title-tussle.html: 4 chunks
# Prepared your-guardian-sport-weekend-tour-de-france-the-open-and-women-s-euro-2025.html: 3 chunks
# Prepared your-guardian-sport-weekend-women-s-cricket-world-cup-final-old-firm-clash-and-more.html: 3 chunks
# Prepared your-guardian-sport-weekend-women-s-rugby-world-cup-final-ryder-cup-premier-league-and-more.html: 3 chunks
# Prepared your-guardian-sport-weekend-women-s-rugby-world-cup-quarters-manchester-derby-and-more.html: 5 chunks
# Prepared your-guardian-sport-weekend-women-s-rugby-world-cup-semis-azerbaijan-grand-prix-and-more.html: 4 chunks
# Prepared your-guardian-sport-weekend-women-s-rugby-world-cup-us-open-tennis-and-more.html: 3 chunks
# Prepared your-guardian-sport-weekend-world-cup-qualifiers-nfl-and-the-grand-final.html: 3 chunks
# Prepared your-guardian-sport-weekend-wsl-finale-lions-stars-on-show-and-el-cl-sico.html: 3 chunks
# Prepared your-guardian-sport-weekend-wsl-kick-off-an-england-double-header-and-more.html: 4 chunks
# Prepared your-journey-your-way-by-horatio-clare-review-the-martin-lewis-of-mental-health.html: 2 chunks
# Prepared your-reservation-is-at-risk-beware-the-booking-com-scam.html: 2 chunks
# Prepared youth-crime-in-regional-nsw-down-12-with-even-sharper-drops-in-crime-hotspots.html: 2 chunks
# Prepared youth-culture-experts-could-help-avoid-stereotyping-of-young-black-men-say-lawyers.html: 2 chunks
# Prepared youth-demand-pro-palestinian-protest-blocks-traffic-in-london.html: 1 chunks
# Prepared youth-led-us-climate-activists-widen-focus-to-fight-authoritarianism.html: 3 chunks
# Prepared youtube-agrees-to-pay-trump-24-5m-to-settle-lawsuit-over-account-suspension.html: 2 chunks
# Prepared youtube-most-popular-first-tv-destination-for-children-ofcom-finds.html: 2 chunks
# Prepared youtube-removes-advertising-from-account-accused-of-homophobic-abuse.html: 2 chunks
# Prepared yto-barrada-review-unravelling-the-threads-of-colonialism-one-pretty-silk-at-a-time.html: 2 chunks
# Prepared yuri-honing-goldbrun-review-hums-with-hidden-spontaneity.html: 1 chunks
# Prepared yvette-cooper-accused-of-pushing-children-towards-people-smugglers-by-halting-refugee-scheme.html: 3 chunks
# Prepared yvette-cooper-defends-children-as-young-as-13-needing-digital-id-as-it-happened.html: 18 chunks
# Prepared yvette-cooper-risks-windrush-type-scandal-by-rushing-asylum-response-says-amber-rudd.html: 2 chunks
# Prepared yvette-cooper-to-create-new-offence-to-cover-non-terrorist-planning-of-attacks.html: 2 chunks
# Prepared zachary-rolfe-offered-speaking-services-on-leadership-ethical-decision-making-for-up-to-10-000.html: 2 chunks
# Prepared zack-polanski-s-eco-populism-could-put-voters-off-greens-opponents-say.html: 2 chunks
# Prepared zack-polanski-s-victory-brings-hope-for-a-new-kind-of-politics.html: 2 chunks
# Prepared zainab-johnson-toxically-optimistic-review-us-comic-targets-gun-culture.html: 1 chunks
# Prepared zambia-remove-us-based-players-due-to-trump-immigration-policy-fears.html: 1 chunks
# Prepared zarah-sultana-consults-defamation-lawyers-after-spat-with-jeremy-corbyn-over-party-funds.html: 2 chunks
# Prepared zarif-the-10-funniest-things-i-have-ever-seen-on-the-internet.html: 3 chunks
# Prepared zbig-a-bracing-life-of-carter-s-abrasive-national-security-adviser.html: 3 chunks
# Prepared zelenskiy-lobbies-for-support-and-investment-to-reconstruct-ukraine.html: 2 chunks
# Prepared zelenskyy-accuses-allies-of-wasting-time-as-he-prepares-for-trump-meeting.html: 2 chunks
# Prepared zelenskyy-accuses-russia-of-assault-on-humanity-after-latest-drone-barrage.html: 3 chunks
# Prepared zelenskyy-accuses-west-of-zero-real-reaction-to-russia-s-bombardment.html: 2 chunks
# Prepared zelenskyy-calls-trump-s-proposal-to-freeze-war-at-current-frontlines-good-compromise.html: 2 chunks
# Prepared zelenskyy-claims-reconnaissance-drones-entered-ukrainian-airspace-from-hungary-as-it-happened.html: 11 chunks
# Prepared zelenskyy-condemns-russia-s-vile-and-cowardly-12-hour-bombing-of-ukraine.html: 3 chunks
# Prepared zelenskyy-condemns-vile-and-deadly-russian-strikes-on-ukraine-denmark-bans-all-civilian-drones-for-eu-summit-as-it-happened.html: 8 chunks
# Prepared zelenskyy-employs-strategic-optimism-to-highlight-russia-s-abundant-bad-faith.html: 2 chunks
# Prepared zelenskyy-europe-cannot-guarantee-ukraine-s-security-without-america.html: 4 chunks
# Prepared zelenskyy-fully-committed-to-constructive-dialogue-with-us-after-trump-defends-putin-as-it-happened.html: 14 chunks
# Prepared zelenskyy-invites-pope-leo-to-ukraine-as-pontiff-urges-journalists-to-report-truth.html: 2 chunks
# Prepared zelenskyy-may-be-asked-to-cede-land-to-russia-at-trump-meeting-in-washington.html: 2 chunks
# Prepared zelenskyy-says-he-will-nominate-trump-for-nobel-peace-prize-if-he-secures-ukraine-ceasefire-as-it-happened.html: 14 chunks
# Prepared zelenskyy-says-he-would-join-trump-putin-summit-in-hungary-if-invited-as-it-happened.html: 12 chunks
# Prepared zelenskyy-says-ukraine-can-help-europe-counter-russian-drone-incursions.html: 2 chunks
# Prepared zelenskyy-to-fly-to-washington-as-merz-says-us-ready-to-be-part-of-ukraine-security-guarantees-as-it-happened.html: 32 chunks
# Prepared zelenskyy-to-visit-london-for-talks-before-expected-trump-putin-summit.html: 3 chunks
# Prepared zero-carbon-beer-is-a-myth-how-to-make-brewing-greener.html: 2 chunks
# Prepared zero-hours-contracts-peers-accused-of-trying-to-block-stronger-uk-workers-rights.html: 2 chunks
# Prepared zero-review-senegalese-time-bomb-thriller-is-a-blast.html: 2 chunks
# Prepared zimbabwe-starts-compensating-white-farmers-25-years-after-land-seizures.html: 1 chunks
# Prepared zoe-aldcroft-to-miss-england-s-next-two-games-in-women-s-rugby-world-cup.html: 2 chunks
# Prepared zohran-mamdani-has-upended-us-politics-now-he-should-take-on-fifa.html: 4 chunks
# Prepared zohran-mamdani-s-fifa-fight-is-a-blueprint-for-the-left-to-re-engage-with-sports.html: 3 chunks
# Prepared zohran-mamdani-s-win-shows-the-power-of-mobilizing-non-voters.html: 3 chunks
# Prepared zohran-mamdani-showed-how-it-s-done-identity-politics-can-win-elections.html: 3 chunks
# Prepared zohran-mamdani-shows-how-democrats-can-defeat-authoritarians-like-trump.html: 3 chunks
# Prepared zuckerberg-claims-superintelligence-is-now-in-sight-as-meta-lavishes-billions-on-ai.html: 3 chunks
# Prepared zuckerberg-hailed-ai-superintelligence-then-his-smart-glasses-failed-on-stage.html: 3 chunks
# Prepared zuckerberg-s-swerve-how-diversity-went-from-being-a-meta-priority-to-getting-cancelled.html: 6 chunks
# Prepared zuckerberg-says-meta-will-build-data-center-the-size-of-manhattan-in-latest-ai-push.html: 1 chunks
# Batches:   0%|          | 0/718 [00:00<?, ?it/s]
# Embeddings shape: (45915, 384)
# Saved embeddings to /Users/perso/Documents/Agents/Agentic_Times/data/vectors_base/embeddings.npy
# Saved metadata to /Users/perso/Documents/Agents/Agentic_Times/data/vectors_base/metadata.jsonl
