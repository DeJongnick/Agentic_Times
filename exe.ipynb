# %%
from agents.orchestrator import exe

# %%
exe('Why Yann Lecun rumored to quit Meta?', authors=['John Doe'])
# Out:
# Project root: e:\Ecole\Albert School\MSc1 2025-2026\DAT0732-2 Agentic AI\Project\Agentic_Times
# Embeddings path: e:\Ecole\Albert School\MSc1 2025-2026\DAT0732-2 Agentic AI\Project\Agentic_Times\data\vectors_base\embeddings.npy
# Embeddings exists: True
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# Model loaded.
# Loaded 45915 embeddings and 45915 metadata entries
#
# --- Iteration 1 ---
# Critic note: 8.5 / 10 (threshold: 8.0)
#
# Current article draft:
#
# [title] Unraveling the Rumors: Why Yann LeCun Might Leave Meta
#
# [subtitle] The Context of Innovation and Transition in AI
# ...
