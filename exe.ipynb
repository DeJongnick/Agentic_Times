# %%
import sys
from pathlib import Path

project_root = Path("/Users/perso/Documents/Agents/Agentic_Times")
sys.path.insert(0, str(project_root))

from agents.analyser_collector import UserRequestFormatter, AnalyserCollector
from agents.vector_db import VectorDBClient
from agents.plan_writer import PlanWriter

# %%
def get_context_for_request(user_request):
    
    formatter = UserRequestFormatter(
        provider="azure",
        model="gpt-4o-mini",
        allow_fallback=True
    )

    ROOT = project_root
    EMBEDDINGS_PATH = ROOT / "data" / "vectors_base" / "embeddings.npy"
    METADATA_PATH = ROOT / "data" / "vectors_base" / "metadata.jsonl"
    RAW_DIR = ROOT / "data" / "raw"

    vector_db_client = VectorDBClient(
        embeddings_path=str(EMBEDDINGS_PATH),
        metadata_path=str(METADATA_PATH),
        raw_dir=str(RAW_DIR) if RAW_DIR.exists() else None
    )

    analyser_collector = AnalyserCollector(
        vector_db_client=vector_db_client,
        top_k=5,
        similarity_threshold=0.3,
        request_formatter=formatter  
    )

    context = analyser_collector.corpus_context(user_request)
    return context

# %%
user_request = 'I want to write an article about agriculture in France'
articles = get_context_for_request(user_request)

plan_writer = PlanWriter(provider="openai", model="gpt-4o-mini")

plan = plan_writer.format(
    user_request="I want to write an article about renewable energy",
    articles=articles
)

print(plan)
# Out:
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# Model loaded.
# Loaded 27251 embeddings and 27251 metadata entries
# Here's a comprehensive plan for your article on renewable energy:
#
# ### Title:
# "Powering the Future: The Transformative Impact of Renewable Energy on Our Planet"
#
# ---
#
# ### Subtitle:
# "How Renewable Energy Sources Are Shaping Our Economy, Environment, and Everyday Lives"
#
# ---
#
# ### Date:
# **[Insert Publication Date]**
#
# ---
#
# ### Author:
# **[Your Name]**
#
# ---
#
# ### **I. Introduction**
# - **Hook:** Open with a compelling statistic about renewable energy growth or climate change impacts.
# - **Thesis Statement:** Introduce the main argument of the article: the importance and potential of renewable energy in combating climate change and ensuring sustainable development.
#
# ---
#
# ### **II. Understanding Renewable Energy Types**
# - **A. Solar Energy**
#   - Overview of solar power technology (photovoltaic, solar thermal)
#   - Current global capacity and projections
#   - Examples of successful solar energy projects
# - **B. Wind Energy**
#   - Explanation of wind turbines and offshore wind farms
#   - Statistics on growth in wind energy usage
#   - Case studies of countries leading in wind energy (e.g., Denmark, Germany)
# - **C. Hydroelectric Power**
#   - Discuss how hydroelectric plants operate
#   - Pros and cons, including environmental impacts
#   - Highlight major hydro projects around the world
# - **D. Geothermal Energy**
#   - Explanation of how geothermal energy is harnessed
#   - Current utilization rates and potential
#   - Successful geothermal energy projects
# - **E. Biomass and Bioenergy**
#   - Define biomass energy and its sources
#   - Examples of bioenergy solutions in practice
#
# ---
#
# ### **III. The Economic Impact of Renewable Energy**
# - **A. Job Creation**
#   - Current statistics on jobs in the renewable sector
#   - Future projections for job growth
# - **B. Economic Investment**
#   - Overview of global investment in renewable energy
#   - Impact on local economies and small businesses
# - **C. Cost Comparisons**
#   - Compare costs of renewable energies to fossil fuels
#   - Discuss the drop in prices for renewables over the last decade
#
# ---
#
# ### **IV. Environmental Benefits**
# - **A. Reduction of Greenhouse Gas Emissions**
#   - Statistics on emissions reduced by renewables
#   - Long-term environmental benefits
# - **B. Conservation of Natural Resources**
#   - Discussion on reducing dependency on fossil fuels
# - **C. Biodiversity and Ecosystem Protection**
#   - How renewable energy contributes to preserving ecosystems
#
# ---
#
# ### **V. Challenges Facing Renewable Energy**
# - **A. Infrastructure Issues**
#   - Need for upgrades to the power grid
#   - Battery storage technology developments
# - **B. Policy and Regulatory Barriers**
#   - Overview of current policies in major countries
#   - Suggestions for effective policy frameworks
# - **C. Public Perception and Acceptance**
#   - Common misconceptions about renewable energy
#   - Importance of public education and outreach
#
# ---
#
# ### **VI. The Future of Renewable Energy**
# - **A. Innovations on the Horizon**
#   - Discuss upcoming technologies and improvements (e.g., smart grids, energy access)
# - **B. Global Cooperation**
#   - The role of international agreements (e.g., Paris Agreement)
#   - Importance of collaboration between nations
# - **C. Vision for Sustainable Development**
#   - Integration of renewable energy in achieving the UN Sustainable Development Goals
#
# ---
#
# ### **VII. Conclusion**
# - **Summary of Key Points:** Reiterate the transformative potential of renewable energy.
# - **Call to Action:** Encourage readers to support renewable energy initiatives and make sustainable choices.
#
# ---
#
# ### **VIII. Sources**
# 1. International Renewable Energy Agency (IRENA) - Reports and statistics on renewable energy growth and capacity.
# 2. Global Wind Energy Council - Annual statistics and reports on wind energy.
# 3. The Solar Energy Industries Association (SEIA) - Market reports on solar energy.
# 4. National Renewable Energy Laboratory (NREL) - Research on renewable technology advancements.
# 5. Books and articles by experts in the field of renewable energy and climate science.
#
# ---
#
# ### **IX. Additional Resources**
# - Links to relevant documentaries, TED talks, and organizations working in the renewable energy sector.
# - Suggest local events or community initiatives focused on renewable energy education.
#
# ---
#
# This plan is designed to provide an in-depth exploration of renewable energy while supporting your main argument with comprehensive data, expert opinions, and case studies. Adjust the sections as needed based on your focus and audience.
