# %%
def find_relevant_articles(user_request):
    """
    Interroge la base vectorielle pour trouver les articles pertinents.
    Args:
        user_request (str): La requête de l'utilisateur.
    Returns:
        list: Liste d'articles pertinents.
    """
    
    return
