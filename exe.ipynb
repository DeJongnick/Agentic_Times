# %%
from agents.orchestrator import exe

# %%
exe('Write an article about French terrorism attacks 13 nov.', 
    authors=['John Doe','Max Planck'],
    note_threshold=8.0,
    max_iter=5,
    )
# Out:
# Project root: /Users/perso/Documents/Agents/Agentic_Times
# Embeddings path: /Users/perso/Documents/Agents/Agentic_Times/data/vectors_base/embeddings.npy
# Embeddings exists: True
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# Model loaded.
# Loaded 45915 embeddings and 45915 metadata entries
#
# --- Iteration 1 ---
# Critic note: 8.2 / 10 (threshold: 8.0)
#
# Current article draft:
#
# [title] The Echoes of November 13: Understanding the Impact of France's Terrorism Attacks
#
# [subtitle] Unfolding the Tragedy: Events of November 13
# [paragraph] The night of November 13, 2015, marked a gruesome chapter in history when coordinated terrorist attacks shook Paris, claiming 130 lives and injuring hundreds more, prompting international condemnation and fear. This series of assaults, which remains one of the deadliest attacks in Europe in recent history, left an indelible mark on the consciousness of not just France, but the global community as well.
#
# ...
