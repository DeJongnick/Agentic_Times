# %%
import sys
from pathlib import Path

project_root = Path("/Users/perso/Documents/Agents/Agentic_Times")
sys.path.insert(0, str(project_root))

from agents.analyser_collector import AnalyserCollector
from agents.vector_db import VectorDBClient

# %%
# Chemins vers les fichiers de la base vectorielle
ROOT = project_root
EMBEDDINGS_PATH = ROOT / "data" / "vectors_base" / "embeddings.npy"
METADATA_PATH = ROOT / "data" / "vectors_base" / "metadata.jsonl"
RAW_DIR = ROOT / "data" / "raw"

# Initialisation du client de base vectorielle
vector_db_client = VectorDBClient(
    embeddings_path=str(EMBEDDINGS_PATH),
    metadata_path=str(METADATA_PATH),
    raw_dir=str(RAW_DIR) if RAW_DIR.exists() else None
)
# Out:
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# Model loaded.
# Loaded 13700 embeddings and 13700 metadata entries

# %%
# Initialisation de l'AnalyserCollector
analyser_collector = AnalyserCollector(
    vector_db_client=vector_db_client,
    top_k=5,
    similarity_threshold=0.3
)

# %%
user_request = "Macron"
articles = analyser_collector.find_relevant_articles(user_request)

# %%
articles
# Out:
# [{'source': 'macron-summons-parties-for-crunch-meeting-in-frantic-effort-to-appoint-pm.html',
#   'chunks': [{'source': 'macron-summons-parties-for-crunch-meeting-in-frantic-effort-to-appoint-pm.html',
#     'chunk_index': 0,
#     'score': 0.525079071521759,
#     'metadata': {'source': 'macron-summons-parties-for-crunch-meeting-in-frantic-effort-to-appoint-pm.html',
#      'chunk_index': 0,
#      'num_tokens': 500,
#      'row_index': 6293}}],
#   'max_score': 0.525079071521759,
#   'avg_score': 0.525079071521759},
#  {'source': 'macron-reappoints-s-bastien-lecornu-as-french-prime-minister.html',
#   'chunks': [{'source': 'macron-reappoints-s-bastien-lecornu-as-french-prime-minister.html',
#     'chunk_index': 1,
#     'score': 0.5087313652038574,
#     'metadata': {'source': 'macron-reappoints-s-bastien-lecornu-as-french-prime-minister.html',
#      'chunk_index': 1,
#      'num_tokens': 325,
#      'row_index': 6292}}],
#   'max_score': 0.5087313652038574,
#   'avg_score': 0.5087313652038574},
#  {'source': 'macron-the-trump-whisperer-works-his-magic-but-us-and-europe-remain-an-ocean-apart.html',
#   'chunks': [{'source': 'macron-the-trump-whisperer-works-his-magic-but-us-and-europe-remain-an-ocean-apart.html',
#     'chunk_index': 0,
#     'score': 0.49047914147377014,
#     'metadata': {'source': 'macron-the-trump-whisperer-works-his-magic-but-us-and-europe-remain-an-ocean-apart.html',
#      'chunk_index': 0,
#      'num_tokens': 500,
#      'row_index': 6335}}],
#   'max_score': 0.49047914147377014,
#   'avg_score': 0.49047914147377014},
#  {'source': 'budget-compromise-needed-if-pm-ousted-says-french-finance-minister.html',
#   'chunks': [{'source': 'budget-compromise-needed-if-pm-ousted-says-french-finance-minister.html',
#     'chunk_index': 1,
#     'score': 0.4902553856372833,
#     'metadata': {'source': 'budget-compromise-needed-if-pm-ousted-says-french-finance-minister.html',
#      'chunk_index': 1,
#      'num_tokens': 180,
#      'row_index': 1467}}],
#   'max_score': 0.4902553856372833,
#   'avg_score': 0.4902553856372833},
#  {'source': 'macrons-to-submit-scientific-evidence-to-us-court-to-prove-brigitte-was-not-born-a-man.html',
#   'chunks': [{'source': 'macrons-to-submit-scientific-evidence-to-us-court-to-prove-brigitte-was-not-born-a-man.html',
#     'chunk_index': 0,
#     'score': 0.48516690731048584,
#     'metadata': {'source': 'macrons-to-submit-scientific-evidence-to-us-court-to-prove-brigitte-was-not-born-a-man.html',
#      'chunk_index': 0,
#      'num_tokens': 493,
#      'row_index': 6340}}],
#   'max_score': 0.48516690731048584,
#   'avg_score': 0.48516690731048584}]
