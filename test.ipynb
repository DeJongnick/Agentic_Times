# %%
from agents.orchestrator import *

# %%
generate_publishable_article('AI buble')
# Out:
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# Model loaded.
# Loaded 45915 embeddings and 45915 metadata entries
# PosixPath('/Users/perso/Documents/Agents/Agentic_Times/outputs/understanding-the-ai-bubble-signs-risks-and-consequences.html')
