# %%
from agents.orchestrator import *

# %%
result = iterative_draft_improve(user_request='I want to write an article about the salary of Elon Musk of 1000 billion$ with Tesla', note_threshold=7, max_iter=5)
# Out:
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# Model loaded.
# Loaded 45915 embeddings and 45915 metadata entries

# %%
result
# Out:
# {'iterations': 1,
# ...
